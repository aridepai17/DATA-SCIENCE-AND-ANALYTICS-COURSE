# %% [markdown]
# ## STANDARDIZATION AND NORMALIZATION OF DATA

# %% [markdown]
# ## IMPORTING MAJOR LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
wine_df = pd.read_csv(r"C:\winedataset\winequality-red.csv")

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import matplotlib.pyplot as plt

# %%
mmscaler = MinMaxScaler()
minmax = mmscaler.fit_transform(wine_df)
minmax = pd.DataFrame(minmax, columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality'])
minmax
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
sscaler = StandardScaler()
standard = sscaler.fit_transform(wine_df)
standard = pd.DataFrame(standard, columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality'])
standard
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3          1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.382271   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.169427  -0.243707
# 1597      -1.390155          0.654620    -0.775267       -0.382271  -0.264960
# 1598      -1.332702         -1.216849     1.021999        0.752894  -0.434990
#
# ...

# %%
rscaler = RobustScaler()
robust = rscaler.fit_transform(wine_df)
robust = pd.DataFrame(robust, columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality'])
robust
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.238095              0.72    -0.787879       -0.428571      -0.15
# 1         -0.047619              1.44    -0.787879        0.571429       0.95
# 2         -0.047619              0.96    -0.666667        0.142857       0.65
# 3          1.571429             -0.96     0.909091       -0.428571      -0.20
# 4         -0.238095              0.72    -0.787879       -0.428571      -0.15
# ...             ...               ...          ...             ...        ...
# 1594      -0.809524              0.32    -0.545455       -0.285714       0.55
# 1595      -0.952381              0.12    -0.484848        0.000000      -0.85
# 1596      -0.761905             -0.04    -0.393939        0.142857      -0.15
# 1597      -0.952381              0.50    -0.424242       -0.285714      -0.20
# 1598      -0.904762             -0.84     0.636364        2.000000      -0.60
#
# ...

# %%
plt.figure(figsize = (15,4))
plt.subplot(1, 4, 1)
sns.kdeplot(wine_df['fixed acidity'], color = 'red')
sns.kdeplot(wine_df['citric acid'], color = 'green')
sns.kdeplot(wine_df['total sulfur dioxide'], color = 'blue')
sns.kdeplot(wine_df['alcohol'], color = 'brown')
plt.title('Without Scaling the data')
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.subplot(1, 4, 1)
sns.kdeplot(minmax['fixed acidity'], color = 'red')
sns.kdeplot(minmax['citric acid'], color = 'green')
sns.kdeplot(minmax['total sulfur dioxide'], color = 'blue')
sns.kdeplot(minmax['alcohol'], color = 'brown')
plt.title('Using Min-Max Scaler on the data')
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.subplot(1, 4, 1)
sns.kdeplot(standard['fixed acidity'], color = 'red')
sns.kdeplot(standard['citric acid'], color = 'green')
sns.kdeplot(standard['total sulfur dioxide'], color = 'blue')
sns.kdeplot(standard['alcohol'], color = 'brown')
plt.title('Using Standard Scaler on the data')
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.subplot(1, 4, 1)
sns.kdeplot(robust['fixed acidity'], color = 'red')
sns.kdeplot(robust['citric acid'], color = 'green')
sns.kdeplot(robust['total sulfur dioxide'], color = 'blue')
sns.kdeplot(robust['alcohol'], color = 'brown')
plt.title('Using Robust Scaler on the data')
plt.show()

# %%
wine_df.std()
# Out:
# fixed acidity            1.741096
# volatile acidity         0.179060
# citric acid              0.194801
# residual sugar           1.409928
# chlorides                0.047065
# free sulfur dioxide     10.460157
# total sulfur dioxide    32.895324
# density                  0.001887
# pH                       0.154386
# sulphates                0.169507
# alcohol                  1.065668
# quality                  0.807569
# dtype: float64

# %%
minmax.std()
# Out:
# fixed acidity           0.154079
# volatile acidity        0.122644
# citric acid             0.194801
# residual sugar          0.096570
# chlorides               0.078573
# free sulfur dioxide     0.147326
# total sulfur dioxide    0.116238
# density                 0.138571
# pH                      0.121564
# sulphates               0.101501
# alcohol                 0.163949
# quality                 0.161514
# dtype: float64

# %%
standard.std()
# Out:
# fixed acidity           1.000313
# volatile acidity        1.000313
# citric acid             1.000313
# residual sugar          1.000313
# chlorides               1.000313
# free sulfur dioxide     1.000313
# total sulfur dioxide    1.000313
# density                 1.000313
# pH                      1.000313
# sulphates               1.000313
# alcohol                 1.000313
# quality                 1.000313
# dtype: float64

# %%
robust.std()
# Out:
# fixed acidity           0.829093
# volatile acidity        0.716239
# citric acid             0.590306
# residual sugar          2.014183
# chlorides               2.353265
# free sulfur dioxide     0.747154
# total sulfur dioxide    0.822383
# density                 0.844445
# pH                      0.812560
# sulphates               0.941705
# alcohol                 0.666042
# quality                 0.807569
# dtype: float64

# %% [markdown]
# ## DISTRIBUTION OF DATA WITH SCALERS

# %%
#Without Scaling
plt.figure(figsize = ( 14, 8))
for i, col in enumerate(wine_df.columns, 1):
    plt.title(f'Distribution of {col} Data')
    sns.histplot(wine_df[col], kde = True)
    plt.tight_layout()
    plt.plot()
    plt.show()

# %%
# Min Max Scaler

plt.figure(figsize = ( 14, 8))
for i, col in enumerate(minmax.columns, 1):
    plt.title(f'Distribution of {col} Data')
    sns.histplot(minmax[col], kde=True)
    plt.tight_layout()
    plt.plot()
    plt.show()

# %%
# Standard Scaler

plt.figure(figsize = ( 14, 8))
for i, col in enumerate(standard.columns, 1):
    plt.title(f'Distribution of {col} Data')
    sns.histplot(standard[col], kde=True)
    plt.tight_layout()
    plt.plot()
    plt.show()

# %%
# Robust Scaler

plt.figure(figsize = ( 14, 8))
for i, col in enumerate(robust.columns, 1):
    plt.title(f'Distribution of {col} Data')
    sns.histplot(robust[col], kde=True)
    plt.tight_layout()
    plt.plot()
    plt.show()

# %% [markdown]
# ## CREATING SCATTER PLOT BETWEEN CITRIC ACID AND TOTAL SULFUR DIOXIDE BEFORE AND AFTER SCALING THE DATA

# %%
plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.scatterplot((wine_df['citric acid'], wine_df['total sulfur dioxide']), color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.scatterplot((minmax['citric acid'], minmax['total sulfur dioxide']), color = 'green')
plt.title('After Min-Max Scaling')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.scatterplot((wine_df['citric acid'], wine_df['total sulfur dioxide']), color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.scatterplot((standard['citric acid'], standard['total sulfur dioxide']), color = 'green')
plt.title('After Standard Scaling')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.scatterplot((wine_df['citric acid'], wine_df['total sulfur dioxide']), color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.scatterplot((robust['citric acid'], robust['total sulfur dioxide']), color = 'green')
plt.title('After Min-Max Scaling')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## DISTPLOT BEFORE AND AFTER SCALING THE DATA

# %%
# Min Max Scaler

plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.distplot(wine_df['citric acid'], hist = False )
sns.distplot(wine_df['total sulfur dioxide'], hist = False, color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.distplot(minmax['citric acid'], hist = False )
sns.distplot(minmax['total sulfur dioxide'], hist = False, color = 'blue')
plt.title('After Min-Max Scaling')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\1526292188.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_df['citric acid'], hist = False )
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\1526292188.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Standard Scaler

plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.distplot(wine_df['citric acid'], hist = False )
sns.distplot(wine_df['total sulfur dioxide'], hist = False, color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.distplot(standard['citric acid'], hist = False )
sns.distplot(standard['total sulfur dioxide'], hist = False, color = 'blue')
plt.title('After Min-Max Scaling')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\350349967.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_df['citric acid'], hist = False )
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\350349967.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
# Robust Scaler

plt.figure(figsize =( 15, 5))
plt.subplot(121)
sns.distplot(wine_df['citric acid'], hist = False )
sns.distplot(wine_df['total sulfur dioxide'], hist = False, color = 'red')
plt.title('Before Scaling')

plt.subplot(122)
sns.distplot(robust['citric acid'], hist = False )
sns.distplot(robust['total sulfur dioxide'], hist = False, color = 'blue')
plt.title('After Min-Max Scaling')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\4048495694.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_df['citric acid'], hist = False )
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\4048495694.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## NORMALIZATION

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
maxabsscaler = MaxAbsScaler()
maxabs = maxabsscaler.fit_transform(wine_df)
maxabs = pd.DataFrame(maxabs, columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality'])

maxabs
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.465409          0.443038         0.00        0.122581   0.124386
# 1          0.490566          0.556962         0.00        0.167742   0.160393
# 2          0.490566          0.481013         0.04        0.148387   0.150573
# 3          0.704403          0.177215         0.56        0.122581   0.122750
# 4          0.465409          0.443038         0.00        0.122581   0.124386
# ...             ...               ...          ...             ...        ...
# 1594       0.389937          0.379747         0.08        0.129032   0.147300
# 1595       0.371069          0.348101         0.10        0.141935   0.101473
# 1596       0.396226          0.322785         0.13        0.148387   0.124386
# 1597       0.371069          0.408228         0.12        0.129032   0.122750
# 1598       0.377358          0.196203         0.47        0.232258   0.109656
#
# ...

# %%
plt.subplot(122)
sns.distplot(maxabs['citric acid'], hist = False )
sns.distplot(maxabs['total sulfur dioxide'], hist = False, color = 'blue')
plt.title('After Max Abs Scaling')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\1396674334.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(maxabs['citric acid'], hist = False )
# C:\Users\aride\AppData\Local\Temp\ipykernel_10796\1396674334.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.subplot(122)
sns.scatterplot((maxabs['citric acid'], maxabs['total sulfur dioxide']), color = 'green')
plt.title('After Max Abs Scaling')

plt.tight_layout()
plt.show()
