# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## IMPORTING MAJOR LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\module4\data.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ## CHECKING TYPES OF DATA

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ## DROPPING IRRELEVANT COLUMNS

# %%
df = df.drop(['Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size'], axis=1)

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# ...

# %% [markdown]
# ## RENAMING THE COLUMNS

# %%
df = df.rename( columns = {"Engine HP": "HP", "Engine Cylinders":"Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Model","Highway":"MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})
df
# Out:
#           Make       Model  Year     HP  Cylinders Transmission  \
# 0          BMW  1 Series M  2011  335.0        6.0       MANUAL
# 1          BMW    1 Series  2011  300.0        6.0       MANUAL
# 2          BMW    1 Series  2011  300.0        6.0       MANUAL
# 3          BMW    1 Series  2011  230.0        6.0       MANUAL
# 4          BMW    1 Series  2011  230.0        6.0       MANUAL
# ...        ...         ...   ...    ...        ...          ...
# 11909    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0    AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0    AUTOMATIC
#
#              Drive Model  highway MPG  MPG-C  Price
# 0       rear wheel drive           26     19  46135
# 1       rear wheel drive           28     19  40650
# ...

# %% [markdown]
# ## DROPPING DUPLICATE ROWS

# %%
df.shape
# Out:
# (11914, 10)

# %%
duplicaterows = df[df.duplicated()]
print("Number of duplicate rows: ", duplicaterows.shape)
# Out:
# Number of duplicate rows:  (989, 10)

# %%
df = df.drop_duplicates()
df
# Out:
#           Make       Model  Year     HP  Cylinders Transmission  \
# 0          BMW  1 Series M  2011  335.0        6.0       MANUAL
# 1          BMW    1 Series  2011  300.0        6.0       MANUAL
# 2          BMW    1 Series  2011  300.0        6.0       MANUAL
# 3          BMW    1 Series  2011  230.0        6.0       MANUAL
# 4          BMW    1 Series  2011  230.0        6.0       MANUAL
# ...        ...         ...   ...    ...        ...          ...
# 11909    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0    AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0    AUTOMATIC
#
#              Drive Model  highway MPG  MPG-C  Price
# 0       rear wheel drive           26     19  46135
# 1       rear wheel drive           28     19  40650
# ...

# %% [markdown]
# ## DROP THE MISSING AND NULL VALUES

# %%
df.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Model      0
# highway MPG      0
# MPG-C            0
# Price            0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Make            10827
# Model           10827
# Year            10827
# HP              10827
# Cylinders       10827
# Transmission    10827
# Drive Model     10827
# highway MPG     10827
# MPG-C           10827
# Price           10827
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Drive Model     0
# highway MPG     0
# MPG-C           0
# Price           0
# dtype: int64

# %% [markdown]
# ## DETECTING OUTLIERS

# %%
sns.boxplot(x = df['Price'])
plt.show()

# %%
sns.boxplot(x = df['HP'])
plt.show()

# %%
# Step 1: Select only numeric columns
df_numeric = df.select_dtypes(include='number')

# Step 2: Compute IQR
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1

# Step 3: Create a mask to identify non-outlier rows
mask = ~((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR))).any(axis=1)

# Step 4: Apply the mask to the full original DataFrame
df = df[mask]
df
# Out:
#           Make       Model  Year     HP  Cylinders Transmission  \
# 0          BMW  1 Series M  2011  335.0        6.0       MANUAL
# 1          BMW    1 Series  2011  300.0        6.0       MANUAL
# 2          BMW    1 Series  2011  300.0        6.0       MANUAL
# 3          BMW    1 Series  2011  230.0        6.0       MANUAL
# 4          BMW    1 Series  2011  230.0        6.0       MANUAL
# ...        ...         ...   ...    ...        ...          ...
# 11909    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0    AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0    AUTOMATIC
#
#              Drive Model  highway MPG  MPG-C  Price
# 0       rear wheel drive           26     19  46135
# 1       rear wheel drive           28     19  40650
# ...

# %%
df.shape
# Out:
# (9191, 10)

# %% [markdown]
# ## PLOT DIFFERENT FEATURES AGAINST ONE ANOTHER USING SCATTER PLOT, HISTOGRAM AND HEAT MAP

# %%
# Histogram

df.Make.value_counts().nlargest(40).plot(kind = 'bar', figsize = (10, 5))
plt.title('Number of Cars by Make')
plt.ylabel('Number of Cars')
plt.xlabel('Make')
plt.show()

# %%
## Scatter Plot

fig, ax = plt.subplots(figsize = ( 10, 6))
ax.scatter(df['HP'], df['Price'])
ax.set_xlabel('HP')
ax.set_ylabel('Price')
plt.show()

# %%
# Heat Map
df_numeric = df.select_dtypes(include='number')

# Step 2: Compute correlation matrix
corr_mat = df_numeric.corr()

# Step 3: Plot the heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_mat, cmap='coolwarm', annot=True, fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
